# %%
# %matplotlib inline
import xlrd
import numpy as np
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import os as os
from itertools import product
import scipy.stats as ss
from scipy.stats import norm
from math import e
np.set_printoptions(suppress=True, linewidth=200, edgeitems=100)

# %%
import cx_Oracle

conn = cx_Oracle.connect('XXAPPS/f3b7ce2a3b@vdb1.depauw.edu:1521/DPUPL1')
cursor = conn.cursor()

# %% [markdown]
# # Data loading from All Lines file and Metronet Phone Users file

# %%
lines_df = pd.read_csv('All Lines DePauw.csv')
metronet_df = pd.read_csv('Metronet Phone Users.csv')

# %% [markdown]
# # Data cleansing from given files

# %% [markdown]
# ## Check duplicated numbers

# %%
lines_df[lines_df.duplicated(['Directory Number'])]
# Out:
# Empty DataFrame
# Columns: [Department, Name, Directory Number]
# Index: []

# %%
metronet_df[metronet_df.duplicated(['Directory Number'])]
# Out:
#          Directory Number  Extension Department Type
# 340  Information Services        NaN        NaN  NaN
# 578  Information Services        NaN        NaN  NaN

# %% [markdown]
# ## Drop duplicated and NaN numbers

# %%
a = lines_df.drop_duplicates(subset=['Directory Number']).dropna(subset=['Directory Number']).reset_index(drop=True)
b = metronet_df.drop_duplicates(subset=['Directory Number']).dropna(subset=['Directory Number']).reset_index(drop=True)

a.describe(include=['O'])
# Out:
#        Department              Name Directory Number
# count        1263              1263             1263
# unique         86              1128             1263
# top          POTS  Charter Telethon   (765) 658 5416
# freq          393                19                1

# %%
b.describe(include=['O'])
# Out:
#        Directory Number         Department  Type
# count              1005                993   993
# unique             1005                889    85
# top      (765) 658 4238  Charter Telethon   POTS
# freq                  1                 19   256

# %% [markdown]
# Now we have unique phone numbers in both files.

# %% [markdown]
# ## Cross-check phone numbers

# %% [markdown]
# See if there is any phone number in Metronet file that does not have a match in All Lines file

# %%
b['Phone Match Check'] = ['Match' if x in list(a['Directory Number'])
    else 'No Match' for x in b['Directory Number']]

b[b['Phone Match Check'] == 'No Match']
# Out:
#          Directory Number  Extension Department Type Phone Match Check
# 255     Alumni Engagement        NaN        NaN  NaN          No Match
# 303              HelpDesk        NaN        NaN  NaN          No Match
# 335  Information Services        NaN        NaN  NaN          No Match
# 434        Media Services        NaN        NaN  NaN          No Match
# 717      Computer Science        NaN        NaN  NaN          No Match

# %% [markdown]
# See if there is any phone number in All Lines file that does not have a match in Metronet file

# %%
a['Phone Match Check'] = ['Match' if x in list(b['Directory Number'])
    else 'No Match' for x in a['Directory Number']]

a[a['Phone Match Check'] == 'No Match']
# Out:
#                           Department                   Name Directory Number  \
# 11             Academic Affairs Dept          Becky Wallace   (765) 658 6555
# 12             Academic Affairs Dept              Ben Hogan   (765) 658 6595
# 13             Academic Affairs Dept            Kelley Hall   (765) 658 6606
# 43                         Admission     School of Music AA   (765) 658 4380
# 52                         Admission          Jeffrey Adams   (765) 658 6082
# ...                              ...                    ...              ...
# 1219               Religious Studies      Religious Studies   (765) 658 6386
# 1238      Sociology and Anthropology          Matthew Oware   (765) 658 6699
# 1243  Student Accessibility Services  Student Accessibility   (765) 658 6267
# 1244  Student Accessibility Services        Meggan Johnston   (765) 658 6551
# 1260                 Women's Studies        Women's Studies   (765) 658 6751
#
#      Phone Match Check
# 11            No Match
# 12            No Match
# 13            No Match
# 43            No Match
# 52            No Match
# ...                ...
# 1219          No Match
# 1238          No Match
# 1243          No Match
# 1244          No Match
# 1260          No Match
#
# [263 rows x 4 columns]

# %% [markdown]
# So for the most part, every number in Metronet file has a corresponding number in All Lines file, but not vice versa. There could be a need to use the Metronet file to check whether a number is POTS/VOIP, but in fact, the All Lines file already has POTS as a value in the department field.

# %% [markdown]
# Therefore, we can use the All Lines file as the primary source instead of combining two files.

# %% [markdown]
# ## Create phone type field

# %%
a['Phone Type'] = ['POTS' if x == 'POTS' else 'VOIP' for x in a['Department']]

c = a.drop(['Phone Match Check'],axis='columns')

c['Directory Number'] = c['Directory Number'].str.replace('(','',
                        regex=True).str.replace(')','',
                        regex=True).str.replace(' ','',regex=True)

c['Extension'] = [x[-4:] for x in c['Directory Number']]

c['First Name'] = [x.split( )[0] for x in c['Name']]
c['Last Name'] = [x.split( )[-1] for x in c['Name']]
c['Adhoc Name'] = c['First Name'].str[:2]+' '+c['Last Name']

c = c[['Directory Number','Extension','Name','First Name','Last Name','Adhoc Name','Department','Phone Type']]
c
# Out:
#      Directory Number Extension              Name  First Name Last Name  \
# 0          7656584070      4070     Tamara Stasik      Tamara    Stasik
# 1          7656584091      4091    Corinne Wagner     Corinne    Wagner
# 2          7656584159      4159    Valerie O'Hair     Valerie    O'Hair
# 3          7656584303      4303    Jeane Pope Lab       Jeane       Lab
# 4          7656584358      4358   Bridget Gourley     Bridget   Gourley
# ...               ...       ...               ...         ...       ...
# 1258       7656581041      1041  Christina Holmes   Christina    Holmes
# 1259       7656584759      4759  Leigh-Anne Goins  Leigh-Anne     Goins
# 1260       7656586751      6751   Women's Studies     Women's   Studies
# 1261       7656581088      1088     Womens Center      Womens    Center
# 1262       7656584173      4173        Sarah Ryan       Sarah      Ryan
#
#       Adhoc Name             Department Phone Type
# 0      Ta Stasik  Academic Affairs Dept       VOIP
# 1      Co Wagner  Academic Affairs Dept       VOIP
# 2      Va O'Hair  Academic Affairs Dept       VOIP
# 3         Je Lab  Academic Affairs Dept       VOIP
# 4     Br Gourley  Academic Affairs Dept       VOIP
# ...          ...                    ...        ...
# 1258   Ch Holmes        Women's Studies       VOIP
# 1259    Le Goins        Women's Studies       VOIP
# 1260  Wo Studies        Women's Studies       VOIP
# 1261   Wo Center          Womens Center       VOIP
# 1262     Sa Ryan          Womens Center       VOIP
#
# [1263 rows x 8 columns]

# %% [markdown]
# ## Fix naming issue

# %% [markdown]
# Names have to be consistent with first name and last name in ADP

# %%
# Create "adhoc name" in merged dataframe-created from given files (done already) and dataframe employee_name, 
# which is just last name and the first two letters of first name

# Create a column names "Correct Name"
# If directory name matches legal name in ADP, column returns legal name
# If directory name matches nickname in ADP, column returns legal name that corresponds to the nickname
# If directory adhoc name matches adhoc name in ADP, column returns legal name that corresponds to the adhoc name
# Else, column returns "No Match"
# Modify the original "Name" column based on the values in "Correct Name" column

# This algorithm will not resolve names with double (hyphenated) last names, unexpected names,
# names of dependent, and names with special character in directory
# Create a function and a (manual) dictionary to replace some "No Match" values by the correct legal names

# The final dataframe can be considered the Master File to be used

query = """
select first_name, last_name, person_type, known_as, first_name||' '||last_name legal_name, 
case when known_as is not null then known_as||' '||last_name else null end as nickname,
substr(first_name,1,2)||' '||last_name adhoc_name

from xxadp_people 

where sysdate between effective_start_date and effective_end_date
and (person_type like '%mployee%' or person_type like '%orker%' or person_type like '%orking%' 
or person_type like '%meritus%' or person_type like '%eceased%' or person_type like '%etire%')
"""

cursor.execute(query)
records = cursor.fetchall()

employee_name = pd.DataFrame(records)
employee_name.rename(columns={0: "First Name", 1: "Last Name", 2: "Person Type", 3: "Known As",
                              4: "Legal Name", 5: "Nickname", 6: "Adhoc Name"}, inplace=True)

c['Correct Name'] = [x if x in list(employee_name['Legal Name']) else
    employee_name.loc[employee_name['Nickname'] == x, 'Legal Name'].item() if x in list(employee_name['Nickname']) else
    employee_name.loc[employee_name['Adhoc Name'] == y, 'Legal Name'].iloc[0] if y in list(employee_name['Adhoc Name']) else 
    'No Match' for (x,y) in zip(c['Name'],c['Adhoc Name'])]

c['Name'] = [x if y=='No Match' else y for (x,y) in zip(c['Name'],c['Correct Name'])]

def replace_all(column, dictionary):
    for i, j in dictionary.items():
        column = column.str.replace(i, j, regex=True)
    return column

dictionary = {'Tony Lowe':'Anthony Lowe',
              'Tony Tillman':'Anthony Tillman',
             'C.J. Gomolka':'Carl Gomolka',
              'Bill Smith':'William Smith',
              'Dr. Snelson':'David Snelson',
              'Jamie Stuckey':'Jamie Pell-Stuckey',
              'Kevin Brown':'Kenneth Brown',
             'Pat Babington':'James Babington',
              'B. Charoenphon':'Sutthirut Charoenphon',
              'H Hankinson':'Holbrook Hankinson',
             'S Schillerstrom':'Spencer Schillerstrom',
                'Colleen McCracken':'Colleen McCracken Renick',
              'Kat Gruener':'Valerie Gruener',
              'khadija stewart':'Khadija Stewart',
              'Dr. David Harsha':'David Harsha',
              'Nikki Brueggeman':'Nikki Weber-Brueggeman',
              'Sudha Tiruchengodu Yegyanarayanan':'Sudha Anand',
              'Jo MacPhail':'Josephine MacPhail',
             'Kayla Birt':'Kayla Flegal',
                'Jeannette Johnson-Licon':'Jeannette Johnson',
              'Prakash Deepa':'Deepa Prakash',
                'Mar�a Victoria Luque':'Maria Luque',
              'Samantha Sarich':'Samantha Sarich Nance',
              'S Sarich Nance':'Samantha Sarich Nance',
                  'Soledad Forcadell':'Maria Forcadell',
              'Maureen Langdoc - Gobin':'Maureen Knudsen Langdoc',
              'Kara Stolle/Leonid Sirotkin':'Leonid Sirotkin',
             'Caf�':'Cafe'}

c['Name'] = replace_all(c['Name'],dictionary)

d = c[['Directory Number','Extension','Name','Department','Phone Type']].sort_values(by=['Department'],
                        key=lambda col: col.str.lower()).reset_index(drop=True)
d
# Out:
#      Directory Number Extension              Name             Department  \
# 0          7656584070      4070     Tamara Stasik  Academic Affairs Dept
# 1          7656584091      4091    Corinne Wagner  Academic Affairs Dept
# 2          7656584159      4159    Valerie O'Hair  Academic Affairs Dept
# 3          7656584303      4303    Jeane Pope Lab  Academic Affairs Dept
# 4          7656584358      4358   Bridget Gourley  Academic Affairs Dept
# ...               ...       ...               ...                    ...
# 1258       7656584759      4759  Leigh-Anne Goins        Women's Studies
# 1259       7656581041      1041  Christina Holmes        Women's Studies
# 1260       7656586751      6751   Women's Studies        Women's Studies
# 1261       7656581088      1088     Womens Center          Womens Center
# 1262       7656584173      4173        Sarah Ryan          Womens Center
#
#      Phone Type
# 0          VOIP
# 1          VOIP
# 2          VOIP
# 3          VOIP
# 4          VOIP
# ...         ...
# 1258       VOIP
# 1259       VOIP
# 1260       VOIP
# 1261       VOIP
# 1262       VOIP
#
# [1263 rows x 5 columns]

# %% [markdown]
#  DataFrame d can be considered the master file and the single source of truth.

# %% [markdown]
# # Data loading from ADP Schema

# %% [markdown]
# For comparision purposes, data from ADP must satisfy these conditions:
# - having "658" as the area code
# - belonging to a current employee or a current contingent worker

# %%
query = """
select p.first_name||' '||p.last_name name, p.person_type employment_type, a.address_line1, a.address_line2, a.address_line3, 
a.telephone_number_1, a.telephone_number_2

from xxadp_people p
join xxadp_addresses a
on a.person_id = p.person_id
and (substr(telephone_number_1,1,7) = '765-658' or substr(telephone_number_2,1,7) = '765-658')
and sysdate between a.date_from and nvl(a.date_to, to_date('31-DEC-4712'))

where sysdate between p.effective_start_date and p.effective_end_date
and (p.person_type = 'Employee' or p.person_type like '%Contingent Worker%')

order by telephone_number_1 asc
"""
cursor.execute(query)
records = cursor.fetchall()

e = pd.DataFrame(records)
e.rename(columns={0: "Name", 1: "Employment Type", 2: "Address Line 1", 3: "Address Line 2",
                  4: "Address Line 3", 5: "Campus Phone 1", 6: "Campus Phone 2"}, inplace=True)

e1 = e[~(e['Campus Phone 1'].isnull())][['Name', 'Employment Type',
                                         'Address Line 1','Address Line 2','Address Line 3','Campus Phone 1']]

e1.rename(columns={'Campus Phone 1':'Campus Phone'},inplace=True)

e2 = e[~(e['Campus Phone 2'].isnull())][['Name','Employment Type',
                                         'Address Line 1','Address Line 2','Address Line 3','Campus Phone 2']]

e2.rename(columns={'Campus Phone 2':'Campus Phone'},inplace=True)

e = pd.concat([e1,e2])

e['Campus Phone'] = e['Campus Phone'].replace('-','',regex=True)
e = e[['Campus Phone','Name','Employment Type', 'Address Line 1', 'Address Line 2', 'Address Line 3']]
e
# Out:
#     Campus Phone               Name Employment Type  \
# 0     7656581021        Eliza Brown        Employee
# 1     7656581035       Carl Gomolka        Employee
# 2     7656581036  Christopher Wolfe        Employee
# 3     7656581039       Glen Kuecker        Employee
# 4     7656581041   Christina Holmes        Employee
# ..           ...                ...             ...
# 508   7656586757    Leonid Sirotkin        Employee
# 509   7656586798       Scotty Stepp        Employee
# 510   7656586798       James Beckel        Employee
# 511   7656586799   Curtis Carpenter        Employee
# 512   7656584726    Gloria Townsend        Employee
#
#                             Address Line 1  \
# 0                          School of Music
# 1                    Global French Studies
# 2      Office of University Communications
# 3                                  History
# 4    Women's, Gender and Sexuality Studies
# ..                                     ...
# 508                        School of Music
# 509                        School of Music
# 510                        School of Music
# 511                   Information Services
# 512                  1131 N US Highway 231
#
#                                       Address Line 2        Address Line 3
# 0        Green Center for Performing Arts, Room 1107                  None
# 1                             East College, Room 305                  None
# 2                             101 E. Seminary Street                  None
# 3                            Harrison Hall, Room 221    7 E Larabee Street
# 4                             Asbury Hall, Room 205B                  None
# ..                                               ...                   ...
# 508  Green Center for the Performing Arts, Room 1110                  None
# 509  Green Center for the Performing Arts, Room 0161  600 S. Locust Street
# 510  Green Center for the Performing Arts, Room 0161  701 S College Avenue
# 511  Julian Science and Mathematics Center, Room 166                  None
# 512                            1131 N US Highway 231                  None
#
# [513 rows x 6 columns]

# %% [markdown]
# # Data inconsistencies

# %% [markdown]
# ## Numbers in ADP that are NOT in directory

# %%
e['Phone Match Check'] = ['Match' if x in list(d['Directory Number'])
    else 'No Match' for x in e['Campus Phone']]

e_nomatch = e[(e['Phone Match Check'] == 'No Match') & (e['Campus Phone'].str.len() == 10)]

e_nondir = e_nomatch.groupby(['Campus Phone']).agg({'Name':'sum'})
e_nondir
# Out:
#                                                            Name
# Campus Phone
# 7656584500    Angelique SerranoNicole CollisiHaleigh Chastee...
# 7656584798                                         John Feuquay
# 7656585555    Antoine StewartStephen SmithRobert CarterCamer...
# 7656586570                                        Jia-Ling Weng

# %% [markdown]
# Check the name(s) associated with these non-directory numbers and replace those if necessary

# %%
e_nondir.loc['7656584500'] = 'Housing and Residence Life'
e_nondir.loc['7656585555'] = 'DePauw Police'
e_nondir.rename(columns={'Name_x':'Name'},inplace=True)
e_nondir
# Out:
#                                     Name
# Campus Phone
# 7656584500    Housing and Residence Life
# 7656584798                  John Feuquay
# 7656585555                 DePauw Police
# 7656586570                 Jia-Ling Weng

# %% [markdown]
# We conclude that very few numbers were not recorded in the Master File.

# %% [markdown]
# ## Numbers in directory that are NOT in ADP

# %%
d['Phone Match Check'] = ['Match' if x in list(e['Campus Phone'])
    else 'No Match' for x in d['Directory Number']]

phone_check = d[d['Phone Match Check'] == 'No Match']

col_check = pd.DataFrame(['Match' if x in list(e['Name']) else 'No Match' for x in phone_check['Name']])

phone_check = phone_check.reset_index(drop=True).join(col_check).rename(columns={0:'Name Match Check'})

name_check = phone_check[phone_check['Name Match Check'] == 'Match'][['Directory Number',
            'Extension','Name','Department','Phone Type']]

d_nonadp = name_check.sort_values(by=['Department'],key=lambda col: col.str.lower()).reset_index(drop=True)
d.drop(columns={'Phone Match Check'},inplace=True)

d_nonadp
# Out:
#    Directory Number Extension              Name  \
# 0        7656584070      4070     Tamara Stasik
# 1        7656584358      4358   Bridget Gourley
# 2        7656584601      4601      David Berque
# 3        7656584112      4112    Benjamin Hogan
# 4        7656584034      4034    Dennis Dechant
# ..              ...       ...               ...
# 58       7656584143      4143       Kelley Hall
# 59       7656584835      4835    Raymond Miller
# 60       7656586551      6551   Meggan Johnston
# 61       7656584804      4804  Haleigh Chasteen
# 62       7656584269      4269         Alan Hill
#
#                         Department Phone Type
# 0            Academic Affairs Dept       VOIP
# 1            Academic Affairs Dept       VOIP
# 2            Academic Affairs Dept       VOIP
# 3                Academic Services       VOIP
# 4              Art and Art History       VOIP
# ..                             ...        ...
# 58              Registrar's Office       VOIP
# 59                  Service Center       VOIP
# 60  Student Accessibility Services       VOIP
# 61                    Student Life       VOIP
# 62           Student Life Division       VOIP
#
# [63 rows x 5 columns]

# %% [markdown]
# These people's ADP information needs to be updated. They either have a new phone number, or have two phone numbers and the second one hasn't been recorded.

# %% [markdown]
# ## Numbers in ADP and in directory but under different names

# %%
combined_df = e[['Name','Campus Phone']].merge(d,how='left',left_on='Campus Phone',
            right_on='Directory Number')

combined_df1 = combined_df[~(combined_df['Name_y'].isnull()) & (combined_df['Name_x']!=combined_df['Name_y'])]

combined_df2 = combined_df1[~combined_df1['Name_y'].isin([
    'Psychology',
    'Center for Spiritual Life',
    'Admissions Front Desk',
    'Presidents Office',
    'Facilities AA',
    'Grounds Department',
    'Plumbers',
    'Counseling Services TOD',
    'HelpDesk TOD',
    'Prevo Library Service Desk',
    'Student Post Office phone',
    'School of Music AA',
    'Libraries',
    'Facilities Annex',
    'Dock',
    'Admissions New Hire',
    'English',
    'Biology',
    'Media Services',
    'Political Science',
    'Econ and Management',
    'General Athletics',
    'Lily Equipment Room',
    'Art Department',
    'Peeler Front Desk',
    'Student Accessibility',
    'Economics and Management'
])]

combined_df3 = combined_df2.rename(columns={'Name_x':'Name from ADP','Name_y':'Name from Master File'})

combined_df4 = combined_df3[['Campus Phone','Extension','Name from ADP','Name from Master File','Department']]

dif_df = combined_df4.sort_values(by=['Department'],key=lambda col: col.str.lower()).reset_index(drop=True)
dif_df
# Out:
#    Campus Phone Extension      Name from ADP    Name from Master File  \
# 0    7656584359      4359       David Berque            Brenda Rogers
# 1    7656586606      6606      Matthew Meier              Kelley Hall
# 2    7656586606      6606       Susan Wilson              Kelley Hall
# 3    7656584336      4336         John Berry              Misti Scott
# 4    7656584345      4345     Dennis Dechant              Anne Harris
# 5    7656584012      4012       Nipun Chopra             Melynda Link
# 6    7656584921      4921      Vincent Lazar            Clint Wallman
# 7    7656584940      4940  Dennis Harrington             Russell Loyd
# 8    7656586280      6280        Anne Bourne           Cameron Tucker
# 9    7656584166      4166   Monica Jorgensen               Linan Peng
# 10   7656585943      5943       Koray Sayili      Ehsan Asghari-Ghara
# 11   7656586624      6624        Peter Crary       Jeremiah Sutherlin
# 12   7656584186      4186      Holly Vanatti  Shea Mahoney-Sutherland
# 13   7656584105      4105       Avery Archer            Jeanette Pope
# 14   7656585017      5017        Linda Clute             Megan Havens
# 15   7656584434      4434      Meghan Tipton         Michelle Bignell
# 16   7656586757      6757     Benjamin Smith          Leonid Sirotkin
# 17   7656586350      6350        Thomas King             Barbara Pare
# 18   7656586691      6691    William Pearson        Scott Spiegelberg
# 19   7656586350      6350   Natalia Rachford             Barbara Pare
# 20   7656584506      4506      Nancy Summitt          Matthew Johnson
# 21   7656586798      6798       Scotty Stepp             James Beckel
# 22   7656584437      4437       David Cutler              Annie Weltz
# 23   7656584383      4383        Troy Castle           Kerry Jennings
# 24   7656584360      4360       Ming-Hui Kuo    Spencer Schillerstrom
# 25   7656581076      1076    John Vermillion             Joseph Garbe
# 26   7656584223      4223        Bob Leonard     Erin Confer-Staggers
# 27   7656584147      4147      Aldrin Magaya            Lynda LaRoche
# 28   7656584907      4907        Sheila Cash             David Little
# 29   7656584907      4907      William Green             David Little
# 30   7656586699      6699       Adam Liebman            Matthew Oware
# 31   7656584199      4199          Alan Hill         Mishelle Malayer
#
#                             Department
# 0                Academic Affairs Dept
# 1                Academic Affairs Dept
# 2                Academic Affairs Dept
# 3                  Art and Art History
# 4                  Art and Art History
# 5                            Athletics
# 6                            Athletics
# 7                            Athletics
# 8                            Athletics
# 9             Economics and Management
# 10            Economics and Management
# 11               Facilities Management
# 12                       Financial Aid
# 13                         Geosciences
# 14  Janet Prindle Institute for Ethics
# 15                           Libraries
# 16                    Modern Languages
# 17                               Music
# 18                               Music
# 19                               Music
# 20                               Music
# 21                               Music
# 22                               Music
# 23                               Music
# 24                               Music
# 25           Office for Sustainability
# 26                  Presidential Staff
# 27                  Registrar's Office
# 28                      Service Center
# 29                      Service Center
# 30          Sociology and Anthropology
# 31               Student Life Division

# %% [markdown]
# # Directory Clean-Up

# %% [markdown]
# ## Add missing numbers, location and address

# %%
# Add numbers in ADP that are not in directory
data_to_add = pd.DataFrame({'Directory Number':['7656584500','7656584798','7656585555','7656586570'],
        'Extension':['4500', '4798', '5555', '6570'],
        'Name':['Housing', 'John Feuquay', 'Public Safety', 'Jia-Ling Weng'],
        'Department':['Housing and Residence Living','Media Services','Public Safety','Modern Languages'],
        'Phone Type':['VOIP','VOIP','VOIP','VOIP']})

d_added = d.append(data_to_add, ignore_index = True).sort_values(
    by=['Department'],key=lambda col: col.str.lower()).reset_index(drop=True)

# Create person type column (Faculty, Staff, Organization Number, POTS Number)
query = """
select pv.name, 
case when title like '%rofessor%' or employment_type like '%meritus%'then 'Faculty' 
else 'Staff' end as person_type

from
(select p.person_id, min(p.first_name||' '||p.last_name) name, min(p.person_type) employment_type, 
listagg(ass.ass_attribute1,', ') title
    
from xxadp_people p

left join xxadp_assignments ass
on p.person_id = ass.person_id
and sysdate between ass.effective_start_date and ass.effective_end_date

where sysdate between p.effective_start_date and p.effective_end_date    
and (person_type like '%mployee%' or person_type like '%orker%' or person_type like '%orking%' 
or person_type like '%meritus%' or person_type like '%eceased%' or person_type like '%etire%')

group by p.person_id) pv
"""

cursor.execute(query)
records = cursor.fetchall()

type_df = pd.DataFrame(records)
type_df.rename(columns={0: "Name", 1: "Person Type"}, inplace=True)


d_added['Person Type'] = [type_df.loc[type_df['Name'] == x, 'Person Type'].iloc[0] if x in list(type_df['Name']) 
                            else 'POTS Line' if d_added.loc[d_added['Name'] == x, 'Phone Type'].iloc[0] == 'POTS'
                              else 'Non-DPU or Org. Number' for x in d_added['Name']]

# Fix some department naming
d_added.loc[d_added['Department'] == 'Athletics / Blackstock', 'Department'] ='Athletics'
d_added.loc[d_added['Department'] == 'Conflict Studies', 'Department'] ='Peace and Conflict Studies'
d_added.loc[d_added['Department'] == 'DePauw Police Department', 'Department'] ='DePauw Police'
d_added.loc[d_added['Department'] == 'Information Services / Returned June 2021', 'Department'] ='Information Services'
d_added.loc[d_added['Department'] == 'Music', 'Department'] ='School of Music'
d_added.loc[d_added['Department'] == 'Print Shop', 'Department'] ='Printing Services'
d_added.loc[d_added['Department'] == 'Psychology', 'Department'] ='Psychology and Neuroscience'
d_added.loc[d_added['Department'] == 'Public Safety', 'Department'] ='DePauw Police'
d_added.loc[d_added['Department'] == 'Student Life', 'Department'] ='Student Affairs'
d_added.loc[d_added['Department'] == 'Student Life Division', 'Department'] ='Student Affairs'
d_added.loc[d_added['Department'] == 'Women\'s Studies', 'Department'] ='Women\'s, Gender and Sexuality Studies'
d_added.loc[d_added['Department'] == 'American Academic Leadership', 'Department'] ='Art and Art History'
d_added.loc[d_added['Department'] == 'Conference and Campus Events', 'Department'] ='Facilities Management'
d_added.loc[d_added['Department'] == 'Development and Alumni Engagement', 'Department'] ='Development'
d_added.loc[d_added['Department'] == 'Development Services', 'Department'] ='Development'
d_added.loc[d_added['Department'] == 'Finance', 'Department'] ='Finance and Administration'
d_added.loc[d_added['Department'] == 'Instructional & Learning Svcs', 'Department'] ='Information Services'
d_added.loc[d_added['Department'] == 'Mail Center', 'Department'] ='Facilities Management'
d_added.loc[d_added['Department'] == 'Office of Spiritual Life', 'Department'] ='Center for Spiritual Life'
d_added.loc[d_added['Department'] == 'Performing Arts', 'Department'] ='School of Music'
d_added.loc[d_added['Department'] == 'Service Center', 'Department'] ='Facilities Management'

# Get location and address data from database
query = """
select name, max(location_code), max(address_line_1) 
from xxadp_organizations
where location_code is not null
group by name
order by name
"""

cursor.execute(query)
records = cursor.fetchall()

org = pd.DataFrame(records)
org.rename(columns={0: "Department", 1: "Location", 2: "Address"}, inplace=True)

# Join directory data with department location data
d_merge = d_added.merge(org,how='left',left_on='Department',right_on='Department')

# Manually fix some missing locations
d_merge.loc[d_merge['Department'] == 'bonappetit','Location'] = 'Hoover Hall'
d_merge.loc[d_merge['Department'] == 'bonappetit','Address'] = '101 E Hanna St'

d_merge.loc[d_merge['Department'] == 'Gobin','Location'] = 'Gobin Church'
d_merge.loc[d_merge['Department'] == 'Gobin','Address'] = '305 Simpson St'

d_merge.loc[d_merge['Department'] == 'HelpDesk','Location'] = 'Julian'
d_merge.loc[d_merge['Department'] == 'HelpDesk','Address'] = '602 S College Ave'

d_merge.loc[d_merge['Department'] == 'Housing and Residence Living','Location'] = 'Anderson Street Hall'
d_merge.loc[d_merge['Department'] == 'Housing and Residence Living','Address'] = '413 Anderson St'

d_merge.loc[d_merge['Department'] == 'Media Services','Location'] = 'Julian'
d_merge.loc[d_merge['Department'] == 'Media Services','Address'] = '602 S College Ave'

d_merge = d_merge[['Directory Number','Extension','Name','Person Type','Department','Phone Type','Location','Address']]
d_merge
# Out:
#      Directory Number Extension              Name           Person Type  \
# 0          7656584070      4070     Tamara Stasik               Faculty
# 1          7656584091      4091    Corinne Wagner                 Staff
# 2          7656584159      4159    Valerie O'Hair                 Staff
# 3          7656584303      4303    Jeane Pope Lab  Not Staff or Faculty
# 4          7656584358      4358   Bridget Gourley               Faculty
# ...               ...       ...               ...                   ...
# 1262       7656584759      4759  Leigh-Anne Goins               Faculty
# 1263       7656581041      1041  Christina Holmes               Faculty
# 1264       7656586751      6751   Women's Studies  Not Staff or Faculty
# 1265       7656581088      1088     Womens Center  Not Staff or Faculty
# 1266       7656584173      4173        Sarah Ryan                 Staff
#
#                                  Department Phone Type           Location  \
# 0                     Academic Affairs Dept       VOIP      Harrison Hall
# 1                     Academic Affairs Dept       VOIP      Harrison Hall
# 2                     Academic Affairs Dept       VOIP      Harrison Hall
# 3                     Academic Affairs Dept       VOIP      Harrison Hall
# 4                     Academic Affairs Dept       VOIP      Harrison Hall
# ...                                     ...        ...                ...
# 1262  Women's, Gender and Sexuality Studies       VOIP        Asbury Hall
# 1263  Women's, Gender and Sexuality Studies       VOIP        Asbury Hall
# 1264  Women's, Gender and Sexuality Studies       VOIP        Asbury Hall
# 1265                          Womens Center       VOIP  The Womens Center
# 1266                          Womens Center       VOIP  The Womens Center
#
#                        Address
# 0               7 E Larabee St
# 1               7 E Larabee St
# 2               7 E Larabee St
# 3               7 E Larabee St
# 4               7 E Larabee St
# ...                        ...
# 1262  100 East Seminary Street
# 1263  100 East Seminary Street
# 1264  100 East Seminary Street
# 1265        306 E Hanna Street
# 1266        306 E Hanna Street
#
# [1267 rows x 8 columns]

# %% [markdown]
# ## Add student phone numbers

# %% [markdown]
# Only students entered DePauw in/after Fall 2017-2018 are considered

# %%
query = """
select replace(replace(replace(replace(d.comm_value,'-',''),' ',''),'+',''),'.','') directory_number, null extension,
p.first_name||' '||p.last_name name, 'Student' person_type, 'Student' department, 'VOIP' phone_type,

from xxcs_personmaster_v p
join xxcis_digicomm d
on p.person_id = d.person_id
and sysdate between d.date_from and d.date_to
and d.comm_type_id = 2141

where p.cs_entrance_semester_code >= 2017201820
"""

cursor.execute(query)
records = cursor.fetchall()
records
# Out:
# [('17657202837',
#   None,
#   'James Tate',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3179027522',
#   None,
#   'Annika Whitlock',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7657193328',
#   None,
#   'Ben Gellman',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8475086536',
#   None,
#   'Nicole Nale',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3176540789',
#   None,
#   'SyRia Hudson',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3039496502',
#   None,
#   'Samuel Yeager',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('923005555769',
#   None,
#   'Khadija Abid',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8122437784',
#   None,
#   'Ryan Scott',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7737048517',
#   None,
#   'James Montijo',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3128906039',
#   None,
#   'Jacqueline Guerrero',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7656679396',
#   None,
#   'Hannah Ndow',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7343317856',
#   None,
#   'Ahmad Qayyum',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('9167988089',
#   None,
#   'Xitao Li',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('2243557367',
#   None,
#   'Mary Maloney',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3473722783',
#   None,
#   'Leala Hailey',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3127314785',
#   None,
#   'Jacob Avenaim',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7653761918',
#   None,
#   'Andrew Fowler',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7657215613',
#   None,
#   'Cassie McMullin',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('2602413342',
#   None,
#   'Daniel Shank',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8126550512',
#   None,
#   'Noah Boyd',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('2693635208',
#   None,
#   'Gavin Clarke',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('2162463087',
#   None,
#   'Alexander Murlin',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('2602061914',
#   None,
#   'Arwa Ahmed',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('2605086304',
#   None,
#   'Nana Yaw Quarshie',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8165016700',
#   None,
#   'Robert Cuddy',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8478022406',
#   None,
#   'Nicholas Fenske',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('6143577221',
#   None,
#   'Nicholas Celona',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3146030219',
#   None,
#   'Gabriel Bierschenk',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8167726488',
#   None,
#   'Deresha Billups-Campbell',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7653011526',
#   None,
#   'Siyuan Cheng',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3177030199',
#   None,
#   'Scott Kelley',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('966534154707',
#   None,
#   'Shireen Rahmani',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7653011232',
#   None,
#   'Abdullah Sami',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3176941781',
#   None,
#   'Kamrie Davis',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3177277927',
#   None,
#   'Ethan Rinne',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('2603482235',
#   None,
#   'Audrey Scantlin',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('2405814520',
#   None,
#   'Stacie Frost',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3172500231',
#   None,
#   'Jacob Copeland',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7087816551',
#   None,
#   'Abigail Marchetti',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('2244809076',
#   None,
#   'Alyssa Ramirez',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('9855073512',
#   None,
#   'Lucas Coleman',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3176264961',
#   None,
#   'Trenton Schneider',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7737827562',
#   None,
#   'Karla Concepcion',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('6309951640',
#   None,
#   'Joseph Kwasigroch',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3175043955',
#   None,
#   'Jack Higgs',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8183041439',
#   None,
#   'Christopher Linger',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('9044378179',
#   None,
#   'Samuel Meyer',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3176914893',
#   None,
#   'Taylor Myers',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8125696506',
#   None,
#   'Don Bollinger',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7022655416',
#   None,
#   'Daniel Kinas',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7703106649',
#   None,
#   'Malachi Wright',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7085577414',
#   None,
#   'Will Smith',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('4404822263',
#   None,
#   'Hadley Drake',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3175044200',
#   None,
#   'Karrajah Smith',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('821064702098',
#   None,
#   'Ji Hyun Kim',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7652749114',
#   None,
#   'Breanna DeYoung',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3175609691',
#   None,
#   'Samuel Voelz',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3129729358',
#   None,
#   'Hadley Bushonville',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('6159393254',
#   None,
#   'Brennan Saling',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3176978881',
#   None,
#   'Taytum Schaney',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7083081278',
#   None,
#   'Carter Schultz',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8126989734',
#   None,
#   'Abraham Ramsey',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('4045927614',
#   None,
#   'Natavious Lewis',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3174402798',
#   None,
#   'Samuel Burns',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3173666455',
#   None,
#   'Alexander Gretencord',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8124549330',
#   None,
#   'Emma Stachowski',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7733873328',
#   None,
#   'Nadia Quinones',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('5743359355',
#   None,
#   'Jacob Hamm',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3002555221',
#   None,
#   'Hira Satti',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('9293749408',
#   None,
#   'Fatoumata Barry',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8148973656',
#   None,
#   'Jessica Hess',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8472546013',
#   None,
#   'Katherine Phelps',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8613079295259',
#   None,
#   'Tianyu Wang',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('923349797997',
#   None,
#   'Muhammad Irfan',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('923314216226',
#   None,
#   'Noor Malik',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('4917634495336',
#   None,
#   'Franziska Barisic',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('34633237901',
#   None,
#   'Eduardo Montes Romero',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('9167409557',
#   None,
#   'Joshua McCown',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7653763893',
#   None,
#   'Meghan Hennessey',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('6415835643',
#   None,
#   'Keisuke Ohtani',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7657215966',
#   None,
#   'Whitney Weinschenk',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('2193441190',
#   None,
#   'Rebecca Yaw',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7657210999',
#   None,
#   'Sang Truong',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8126642169',
#   None,
#   'Gage Smitley',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('5038535278',
#   None,
#   'Jacob Brady',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8478774668',
#   None,
#   'Cameron Ihrke',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('9707760862',
#   None,
#   'Angelina Gregg',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7735754765',
#   None,
#   'Anya Sanders',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('2245150957',
#   None,
#   'Justin McMahon',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7657206882',
#   None,
#   'Vy Hoang',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('4058085055',
#   None,
#   'Maggie Ephraim',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('2244012422',
#   None,
#   'Eric Spehlmann',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7653018053',
#   None,
#   'Juan Pablo Arenas Uribe',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3306977852',
#   None,
#   'Emily Cremer',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8476447953',
#   None,
#   'Kathryn Gruner',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('17656333190',
#   None,
#   'Diana Borse',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('2679074167',
#   None,
#   'Annalise Stein',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3479854498',
#   None,
#   'Mahmoud Abouelkheir',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7653467077',
#   None,
#   'Mackenzi Lamb',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7733941158',
#   None,
#   'Maria Santillan',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('17653011039',
#   None,
#   'Yuan Zhuang',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7122993118',
#   None,
#   'Megan Armato',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3176813113',
#   None,
#   'Elisabeth Reese',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3172948896',
#   None,
#   'Grace Stinson',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7652711362',
#   None,
#   'Alyssa Fisher',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3093397081',
#   None,
#   'Katherine Vieck',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8476444163',
#   None,
#   'Emmanuella Carey',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('9133064625',
#   None,
#   'Nicholas Redwine',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('2606154180',
#   None,
#   'Isaac Morken',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3177504940',
#   None,
#   'Kaley Keating',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('2817287795',
#   None,
#   'Jacqueline Ebel',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7657203342',
#   None,
#   'Yuzhen Jiang',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8613248010185',
#   None,
#   'Xinyu Feng',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('6167240206',
#   None,
#   'Joslyn Fox',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8322721027',
#   None,
#   'Syed Hussain Shahryar Bukhari',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3174439484',
#   None,
#   'Annie Watson',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('5153333294',
#   None,
#   'Hira Ahmad',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('2195084219',
#   None,
#   'Sydney Majka',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3176056404',
#   None,
#   'Hannah Hutchison',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3179566077',
#   None,
#   'Kali Mayer',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7657214336',
#   None,
#   'Syed Muhammad Mustafa',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('5135930994',
#   None,
#   'Madison Smith',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3174595888',
#   None,
#   'Katherine Noble',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('2244566392',
#   None,
#   'Andrew Athenson',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3177011803',
#   None,
#   'Natalia Harkness',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('4045737079',
#   None,
#   "Re'Nae Dillard",
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('6264372645',
#   None,
#   'Thomas Samples',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3144713474',
#   None,
#   'Abigail Carpenter',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3179195187',
#   None,
#   'Margaret Fox',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('6309568288',
#   None,
#   'Mariah De La Fuente',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7656554422',
#   None,
#   'Huitian Xia',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7656553294',
#   None,
#   'Ziyi Wang',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7653011953',
#   None,
#   'Zihan Li',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('6033806769',
#   None,
#   'Quan Khuc',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7656555251',
#   None,
#   'Wenbin Xuan',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3176468787',
#   None,
#   'Richard Pasch',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('9176177873',
#   None,
#   'Ivandino Zulkarnaen',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8123456827',
#   None,
#   'Dongxu Yang',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3126149143',
#   None,
#   'Gongxu Wang',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('2193365808',
#   None,
#   'Noah Schuster',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('2192102231',
#   None,
#   'Bree Winter',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3175086527',
#   None,
#   'Katelin Scott',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('12177102813',
#   None,
#   'Samuel Atterberry',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3123637659',
#   None,
#   'Aiping Li',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3147220171',
#   None,
#   'Madeline Green',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('2197819908',
#   None,
#   'Skylar Barnett',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3174483802',
#   None,
#   'Michael Sosnowski',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7409713403',
#   None,
#   'Destiney Davis',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7656555931',
#   None,
#   'Minkyo Park',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8598060501',
#   None,
#   'Katharine McLean',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('0976467809',
#   None,
#   'Pia Ocvirk',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8123500556',
#   None,
#   'Daniela Chaparro',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3173780777',
#   None,
#   'Elmamoune Bouchareb',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7734207121',
#   None,
#   'Arturo Balcazar',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7653011622',
#   None,
#   'Kantaro Komiya',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3147242102',
#   None,
#   'Donna LaMore',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('2602582300',
#   None,
#   'Moises Lopez Soltero',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3176917508',
#   None,
#   'Emma LeMasters',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('2603881303',
#   None,
#   'Gillian Hughes',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7657206222',
#   None,
#   'Shriyanshi Shikha',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7656555471',
#   None,
#   'Jakob Foss',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7657217589',
#   None,
#   'Collin Gasway',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7657211356',
#   None,
#   'Kristy Huang',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7657208160',
#   None,
#   'Izaiah Campbell',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3178539314',
#   None,
#   'Sydni Justice',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('9893881205',
#   None,
#   'Emma Keeton',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('4159632440',
#   None,
#   'Madison Olds',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3172921726',
#   None,
#   'Oliver Shebek',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3176275053',
#   None,
#   'Nikolas Sullivan',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3132445884',
#   None,
#   'Reece Redman',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8477089470',
#   None,
#   'Matthew Barigazzi',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7654388937',
#   None,
#   'Andrew Powell',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8123403087',
#   None,
#   'Lauren Leal',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3142461577',
#   None,
#   'Timothy Fisher',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3169384359',
#   None,
#   'Sarah Schall',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('2164019140',
#   None,
#   'Peter Hollington',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8613795495428',
#   None,
#   'Matthew Kennedy',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('6308542710',
#   None,
#   'Sadie Jurkovic',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('6304606632',
#   None,
#   'Matthew Pfefferman',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('2142065521',
#   None,
#   'Lillian Cameron',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('4432359631',
#   None,
#   'Lilian Rakow',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8125508934',
#   None,
#   'Aaron Rodgers',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('2602715352',
#   None,
#   'Abigail Coolidge',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3175173773',
#   None,
#   'Emmaly Bisard',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('9129963268',
#   None,
#   'Emily Parks',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3143206088',
#   None,
#   'Samuel Bricker',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3128712047',
#   None,
#   'Raif Tariq',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3177646616',
#   None,
#   'Yizheng Shuai',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8613811634025',
#   None,
#   'Tongming Deng',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3174420592',
#   None,
#   'Marianne Marten',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('17653011355',
#   None,
#   'Zihan He',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8615076529338',
#   None,
#   'Muxin Li',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8153863454',
#   None,
#   'Rachel Oosterhoff',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8617749711575',
#   None,
#   'Jieyuan Song',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3173625554',
#   None,
#   'Eric Nitiss',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7732635564',
#   None,
#   'Quinn Riley',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('2164068506',
#   None,
#   'Matthew Strachan',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('923228462775',
#   None,
#   'Usman Anwar',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7082754148',
#   None,
#   'McKenzie Blaze',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('00923458462700',
#   None,
#   'Musa Hussain',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('2192860393',
#   None,
#   'Mikaela Karolzak',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('2194872532',
#   None,
#   'Kinnedi Davis',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3172253226',
#   None,
#   'Sara Russell',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('5156617899',
#   None,
#   'Katherine Claypool',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8123443280',
#   None,
#   'Isaac Jackson',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('18108087705',
#   None,
#   'Ruibo Dan',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8126059139',
#   None,
#   'Braelyn Means',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('5028036470',
#   None,
#   'Breagan Craig',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('5023159641',
#   None,
#   'Max Henderson',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3179031379',
#   None,
#   'Tyler Galbraith',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7653011623',
#   None,
#   'Ngoc Bui',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('919500074059',
#   None,
#   'Devika Kejriwal',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7205453723',
#   None,
#   'Samuel Mathias',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8473479813',
#   None,
#   'Dylan Garvey',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('6508040331',
#   None,
#   'Ethan Black',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3147950588',
#   None,
#   'Amelia Mauldin',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3179039629',
#   None,
#   'Christopher Boone',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7084200955',
#   None,
#   'Sophie Imlach',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3145032853',
#   None,
#   'Jaylen Riley',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8596209303',
#   None,
#   'Katherine Shearer',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7653011604',
#   None,
#   'Ye Liu',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7708141011',
#   None,
#   'Dong Ju Son',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3172243990',
#   None,
#   'Corinne Steele',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('6142826722',
#   None,
#   'Caroline Cruise',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('9257526173',
#   None,
#   'Ithemba Bell',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7657215607',
#   None,
#   'Jameson Artis',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('923331413204',
#   None,
#   'Sheharyar Hussain',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7812906766',
#   None,
#   'Thomas Roddy',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3237175122',
#   None,
#   'Bastien Weisbein',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('5134317404',
#   None,
#   'Logan Storie',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('9292390003',
#   None,
#   'Ismael Sy Savane',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7738794847',
#   None,
#   'Ahjane Franklin',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('22664270735',
#   None,
#   'Noura Ouattara',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7737277452',
#   None,
#   'Bryan Murillo',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8122014219',
#   None,
#   'Brandon Chamberlin',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3316255291',
#   None,
#   'Madison Demos',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('2244154427',
#   None,
#   'Maegan Resuello',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7657211408',
#   None,
#   'Hashleyna Luchmun',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7313947332',
#   None,
#   'Christian Nava',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8593969869',
#   None,
#   'Hayden Simon',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8618518397805',
#   None,
#   'Anqi Qiu',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('5025440095',
#   None,
#   'Alexus Maddox',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3179851819',
#   None,
#   'Zoe Stapleton-Deno',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3123713345',
#   None,
#   'Kahlia Wilbourn',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7179407877',
#   None,
#   'Madeline Claus',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('18478266455',
#   None,
#   'Mercedes Schabel',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3149109221',
#   None,
#   'Noah Hardy',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3176037702',
#   None,
#   'Connor Kennedy',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7735695225',
#   None,
#   'John Berkley',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8476488582',
#   None,
#   'Bennett Gibson',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7089553731',
#   None,
#   'Jailene Valenzuela',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3123750610',
#   None,
#   'Jenny Hsu',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3126628270',
#   None,
#   'Christopher Reyes Ruiz',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('5022494186',
#   None,
#   'Seth Gogel',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8583426439',
#   None,
#   'Annam Tran',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3174457063',
#   None,
#   'James Hoffman',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7657203558',
#   None,
#   'Aaliya Khan',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8126051609',
#   None,
#   'Esther Little',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8613716168970',
#   None,
#   'Yufei Meng',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8128418484',
#   None,
#   'Jason Mundell',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3177465456',
#   None,
#   'Muhammad Khan',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3108087814',
#   None,
#   'Daisy Hummer',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8618743006668',
#   None,
#   'Yuxuan Li',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('923330446801',
#   None,
#   'Muhammad Subzwari',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('4694037750',
#   None,
#   'Nana Imada',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3012198619',
#   None,
#   'Sungyeon Ahn',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8123454091',
#   None,
#   'Yebin Seo',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7657203747',
#   None,
#   'Takuro Wadayama',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('2489714224',
#   None,
#   'Cate Joelson',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('6307039355',
#   None,
#   'Paula Bordera',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3176905542',
#   None,
#   'Kaylin Linder',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('6164812926',
#   None,
#   'Jingying Huang',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3172468220',
#   None,
#   'Imani Graham',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3179319642',
#   None,
#   'Rebecca Derringer',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3176560126',
#   None,
#   'Kelly Garcia',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7738129817',
#   None,
#   'Daniel Flores-Hernandez',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3146919001',
#   None,
#   'Natalie Raskas',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('5134709698',
#   None,
#   'Alyssa Harmann',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('2245515756',
#   None,
#   'Hannah Metzger',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7082504302',
#   None,
#   'Cayden Bonaccorsi',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('2606157174',
#   None,
#   'Abigail Smith',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8617703460951',
#   None,
#   'Weihao Zhang',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('6308801202',
#   None,
#   'Mia Manney',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('2174137818',
#   None,
#   'Sydney Forbes',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7735316440',
#   None,
#   'Nicholas Baxter',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('2487633586',
#   None,
#   'Katie Paulson',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7653653018',
#   None,
#   'Sarah Hennessey',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8126045992',
#   None,
#   'Abigail Gile',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8476502944',
#   None,
#   'Kelly Keefe',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('5633438563',
#   None,
#   'Allison Miller',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3172891920',
#   None,
#   'Hannah Davis',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7653018050',
#   None,
#   'Chee Ying Cristal Chan',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7657200378',
#   None,
#   'Jinzhi Qin',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('4053059636',
#   None,
#   'Catherine Zesiger',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('2196293036',
#   None,
#   'Sergio Carrillo',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3143198215',
#   None,
#   'Vivica Cook',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('6026213736',
#   None,
#   'Colleen Kelly',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('6304416619',
#   None,
#   'Gina Federighi',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3174374785',
#   None,
#   'Alexis Klink',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('6308881099',
#   None,
#   'Nicholas Von Stein',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7653018081',
#   None,
#   'Momoka Goto',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8618313760590',
#   None,
#   'Jinyue Li',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7652345736',
#   None,
#   'Yuji Mao',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('9167787214',
#   None,
#   'Jacob Bauer',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7658489102',
#   None,
#   'Aadhikya Ghimire',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('97695725202',
#   None,
#   'Nemekhbayar Nergui',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7082976501',
#   None,
#   'Anthony Rizzi',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7656554415',
#   None,
#   'Jiayi Huang',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('17853931414',
#   None,
#   'Emma Bailey',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('819035010261',
#   None,
#   'Ryoji Hasegawa',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('17086062730',
#   None,
#   'Julia Keller',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7653011235',
#   None,
#   'Tarinni Kakar',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('2197766174',
#   None,
#   'Kenneth Decker',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8619801025459',
#   None,
#   'Sixuan Pan',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7653011874',
#   None,
#   'Sixuan Pan',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7652479689',
#   None,
#   'Graham Votaw',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7657122247',
#   None,
#   'Yuka Maenaka',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8477705338',
#   None,
#   'William Drevline',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3176660948',
#   None,
#   'Bralin Coleman',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3124474000',
#   None,
#   'Karl Wilson',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8122305276',
#   None,
#   'Samantha Dougherty',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8125498058',
#   None,
#   'Zosha Roberson',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7656554265',
#   None,
#   'Xiao Zhang',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8596196882',
#   None,
#   'Sydney Strup',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3177609270',
#   None,
#   "Mary O'Connor",
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7655419650',
#   None,
#   'Wyatt Jester',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7738428413',
#   None,
#   'Alecia Hawkins',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3178503299',
#   None,
#   'Victoria Zetterberg',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3173736388',
#   None,
#   "Finnian O'Hara",
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8125952878',
#   None,
#   'Katlyn Hunger',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3179973031',
#   None,
#   'David Flannelly',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7042996756',
#   None,
#   'Helen Amaro',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7735752130',
#   None,
#   'Courtney Boyce',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('6303004663',
#   None,
#   'Bennett Curtis',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('2246168354',
#   None,
#   'Julia Rosenberg',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('6122677527',
#   None,
#   'Jonah Jerabek',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3172502937',
#   None,
#   'Adrianna Rogers',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8126394104',
#   None,
#   'Jesse Fromme',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7654324838',
#   None,
#   'Jonathon Tebbe',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7086688976',
#   None,
#   'Chantelle Sanchez',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7184735809',
#   None,
#   'Cassie Persaud',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('5744009971',
#   None,
#   'Nicholas Williams',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3177534691',
#   None,
#   'Maxwell Bohrer',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7653011934',
#   None,
#   'Jingwei Ling',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('2602559337',
#   None,
#   'Sarah Galliher',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('15016552615',
#   None,
#   'Derrick Ousley',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8122493819',
#   None,
#   'Elizabeth Culp',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('9292207137',
#   None,
#   'Jazmine Kerr',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('15549590737',
#   None,
#   'Changshuo Wang',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7655616656',
#   None,
#   'Kyle Kramer',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3146237944',
#   None,
#   'Kathleen Curran',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('2244029784',
#   None,
#   'Helina Samson',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7657191725',
#   None,
#   'Sage Klinger',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3179893109',
#   None,
#   'Jacquelyn Aspling',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7656556347',
#   None,
#   'Xinye Yang',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3123074795',
#   None,
#   'Carlos Martinez',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3177557980',
#   None,
#   'Kennedi Gilbert',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8123456536',
#   None,
#   'Xuanhui Shao',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8125508977',
#   None,
#   'Meher Sheth',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8476509001',
#   None,
#   'Claire Keefe',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7653011452',
#   None,
#   'Yuxing Chen',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3174478433',
#   None,
#   'Catherine Mullin',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7657204095',
#   None,
#   'Xinyu Zhang',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8472263060',
#   None,
#   'Matthew Braun',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('6463206788',
#   None,
#   'Natalie Betances',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('5742862350',
#   None,
#   'William Serf',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('773629989',
#   None,
#   'Hayley Johnson-Cange',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7659389464',
#   None,
#   'Kyler Schaetzle',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('9374144232',
#   None,
#   'Ashley Dapore',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7204314428',
#   None,
#   'Tyler McCoy',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7736291465',
#   None,
#   'Giselle Castaneda',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8127171011',
#   None,
#   'Haley Schwipps',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('6185250825',
#   None,
#   'Hannah Baker',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('4246664036',
#   None,
#   'Caleigh Ranjo',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3179195165',
#   None,
#   'Emily Graves',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7408777733',
#   None,
#   'Brielle Bait',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7739961290',
#   None,
#   "Ja'na Baylor",
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3125937806',
#   None,
#   'Robert Pettas',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('2605195577',
#   None,
#   'Luis Esteban Hernandez-Ros',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3178501859',
#   None,
#   'William Therber',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3172207011',
#   None,
#   'Destiny Peterson',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7657195641',
#   None,
#   'Muhammad Hunzala Leghari',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3177030567',
#   None,
#   'Andrew Cobb',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7405131230',
#   None,
#   'Taylor Carney-DeBord',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7074922466',
#   None,
#   'Kaitlyn Gardner',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7658489600',
#   None,
#   'Masakatsu Amano',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3142857735',
#   None,
#   'The-Anh Nguyen',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7655924940',
#   None,
#   'Holly Buchanan',
#   'Student',
#   'Student',
#   'VOIP',
# ...
#   'Student Location',
#   'Student Address'),
#  ('3177521774',
#   None,
#   'Alec Pipkin',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3179006208',
#   None,
#   'Cheridan Ross',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8123608117',
#   None,
#   'Sage Sherfick',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7657191178',
#   None,
#   'Kien Ta',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('5132255567',
#   None,
#   'Zoe Cappel',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7657122011',
#   None,
#   'Zichen Zhao',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8127047823',
#   None,
#   'Olivia Storz',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3174319962',
#   None,
#   'Trevor Hoftiezer',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('6149497398',
#   None,
#   'Abigail Hutson-Comeaux',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7734567843',
#   None,
#   'Ryan Kupiec',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('2246195553',
#   None,
#   'Abigail Gost',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3177098364',
#   None,
#   'Trevor Conerly',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8083482490',
#   None,
#   'Nathan Sellner',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7652372008',
#   None,
#   'Kirsten Nordland',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('5743068826',
#   None,
#   'Claire Hubner',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7042996747',
#   None,
#   'Patrick Amaro Rivera',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7657217998',
#   None,
#   'Chia-Yu Chuang',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7203400368',
#   None,
#   'Kaelyn Campbell',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7658949501',
#   None,
#   'Autum Cavender',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('0902707110',
#   None,
#   'Khanh Pham',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7653275100',
#   None,
#   'Haiyu Zhang',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('13924828033',
#   None,
#   'Jinghuan Lin',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3174477895',
#   None,
#   'Clayton Troyer',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3145705754',
#   None,
#   'Paige Sanfelippo',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3174734944',
#   None,
#   'Samuel Brooks',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3176047886',
#   None,
#   'Paul Remmler',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8123634736',
#   None,
#   'Sydney Hornberger',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8472870211',
#   None,
#   'Benjamin Streiff',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8123908993',
#   None,
#   'Samuel Heichelbech',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8599125906',
#   None,
#   'Megan Raleigh',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('5026084261',
#   None,
#   'Morgan Flecke',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('2192468846',
#   None,
#   'Natalie Michaels',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('6306051410',
#   None,
#   'Paige Price',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7653275788',
#   None,
#   'Dongbi Li',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('2176903490',
#   None,
#   'Luke Thompson',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7652421371',
#   None,
#   'Grace Filbrun',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3173979521',
#   None,
#   'Luciana Ponader',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3179851296',
#   None,
#   'Taylor Richardson',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3177302005',
#   None,
#   'Michael Lackey',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('2604452199',
#   None,
#   'Luther Hall',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7088304682',
#   None,
#   'Samuel Johnson',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3176544448',
#   None,
#   'Noah Roberts',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3172004115',
#   None,
#   'Maya Caldwell',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3142215640',
#   None,
#   'Emily Kaiser',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('5022032671',
#   None,
#   'Abigail Downs',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7083780209',
#   None,
#   'Madeline Dixon',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3146507860',
#   None,
#   'Gabriela Carretero',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('9017363744',
#   None,
#   'Eli Nations',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('6305449130',
#   None,
#   'Peter Skaluba',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3179704083',
#   None,
#   'Jalyn Crittenden',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3176706699',
#   None,
#   'Ryan Valentine',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('6162385777',
#   None,
#   'Seth Fagen',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3176588395',
#   None,
#   'Ana Salcedo',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7657483969',
#   None,
#   'N. Nial',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('5022032073',
#   None,
#   'Rose Downs',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8125588597',
#   None,
#   'Alexander Spencer',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3176014875',
#   None,
#   'Audrey Boise',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('9735365607',
#   None,
#   'Kysung Tisdale',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8153705198',
#   None,
#   'Mya Shannon',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7658918220',
#   None,
#   'Katherine Stanley',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('6165025576',
#   None,
#   'William Webster',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3174474618',
#   None,
#   'Molly Ruggles',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7658489604',
#   None,
#   'Boyan Ma',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7657199134',
#   None,
#   'Mishal Ali',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3147183226',
#   None,
#   'Taylor Kroner',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3136550455',
#   None,
#   'Natalie Husby',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3175500164',
#   None,
#   'Yuki Harata',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('6159745540',
#   None,
#   'Jack Woods',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('6148006768',
#   None,
#   'Abigail Morris',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3146807331',
#   None,
#   'Christian Vazquez',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8473383297',
#   None,
#   'Elizabeth Anderson',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3279873068',
#   None,
#   'Sydney Jones',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7733069980',
#   None,
#   'Cesar Mendoza',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8478401364',
#   None,
#   'John Brush',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('2247337878',
#   None,
#   'Sophie Metzger',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('6143597523',
#   None,
#   'Hannah Lathrop',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('2192636319',
#   None,
#   'James Havrilla',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3178092187',
#   None,
#   'Carson Janes',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3148252915',
#   None,
#   'Robert Graves',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3176775576',
#   None,
#   'Sarah Herman',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('9082954298',
#   None,
#   'Sarah Goff',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3124081200',
#   None,
#   'John Csehill',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('5138288746',
#   None,
#   'Eva Nicholson',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('2077106662',
#   None,
#   'Allison Duranceau',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('6303107341',
#   None,
#   'Grant Theisen',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3175047546',
#   None,
#   'Sahra Rahimi',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('6143700771',
#   None,
#   'Madelyn DeAscentis',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3177713238',
#   None,
#   'Sarah Bird',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3176175961',
#   None,
#   'Jenna Purichia',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('6198227756',
#   None,
#   'Alison Williams',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3177755496',
#   None,
#   'Lauren Masoncup',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8126865404',
#   None,
#   'Whitaker Lyons',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('5052809202',
#   None,
#   'Rhiannan De Moulin',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('6304296246',
#   None,
#   'Jade Mejia Wick',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3147530284',
#   None,
#   'Laura Nix',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3177266817',
#   None,
#   'Ella Tobias',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3175022267',
#   None,
#   'Rachel Roscoe',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7655801168',
#   None,
#   'Autumn McDaniel',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3146105524',
#   None,
#   'Maria Hewitt',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7733325235',
#   None,
#   'Matteo Curley',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('6308775552',
#   None,
#   'Alissa Dierks',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('5747807337',
#   None,
#   'Leah Smith',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3173845707',
#   None,
#   'Joanna Berry',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3149430563',
#   None,
#   'Elizabeth Bell',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7406921389',
#   None,
#   'Ivy Sedam',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3175085547',
#   None,
#   'Camiryn Henry',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('4803833133',
#   None,
#   'Kuzivakwashe Chinyanya',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('2242214118',
#   None,
#   'Ronnie Ryba',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('2197079209',
#   None,
#   'Marisol Karmel',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('6512309451',
#   None,
#   'Julia Travis',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7657446031',
#   None,
#   'Alexis Manor',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3179374936',
#   None,
#   'Robert Jenkins',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('2016611517',
#   None,
#   'Abigail Morrison',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('2604680069',
#   None,
#   'Charlotte Borland',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('2604371922',
#   None,
#   'Alyssa Luarde',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('4157553876',
#   None,
#   'Maxwell von Doepp',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('6304841640',
#   None,
#   'Olivia Burress',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('2246233248',
#   None,
#   'Marie Spehlmann',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('0034632296563',
#   None,
#   'Muhammad Saram Waraich',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('6308279218',
#   None,
#   'Onyekachi Ezem',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3178404713',
#   None,
#   'Soleil Decher-Morley',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3177712336',
#   None,
#   'Mackenzie Jones',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('6307307654',
#   None,
#   'Caleigh Cramer',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('7657217396',
#   None,
#   'Kristina Mikhailova',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('5025957668',
#   None,
#   'Curran Stevens',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('2403518849',
#   None,
#   'Xavier Fuller',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8154508688',
#   None,
#   'Lauren LaMore',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('3179923012',
#   None,
#   'Matthew Hylton',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ('8478815778',
#   None,
#   'Sophia Featherstone',
#   'Student',
#   'Student',
#   'VOIP',
#   'Student Location',
#   'Student Address'),
#  ...]

# %%
query = """
select replace(replace(replace(replace(d.comm_value,'-',''),' ',''),'+',''),'.','') directory_number, null extension,
p.first_name||' '||p.last_name name, 'Student' person_type, 'Student' department, 'VOIP' phone_type,
'Student Location' location, 'Student Address' address

from xxcs_personmaster_v p
join xxcis_digicomm d
on p.person_id = d.person_id
and sysdate between d.date_from and d.date_to
and d.comm_type_id = 2141

where p.cs_entrance_semester_code >= 2017201820
"""

cursor.execute(query)
records = cursor.fetchall()

student_df = pd.DataFrame(records)
student_df.rename(columns={0: "Directory Number", 1: "Extension", 2: "Name", 3: "Person Type",
                          4:  "Department", 5: "Phone Type", 6: "Location", 7: "Address"}, inplace=True)
student_df
# Out:
#      Directory Number Extension                    Name Person Type  \
# 0          7657214586      None  Sterling Silver - Test     Student
# 1          5744409696      None               Mason Lee     Student
# 2          3146507860      None      Gabriela Carretero     Student
# 3          8473467975      None          Andrew Douglas     Student
# 4          6165405835      None           Thomas Alkema     Student
# ...               ...       ...                     ...         ...
# 2691       7734410420      None          Tamariya Handy     Student
# 2692       9196274369      None            Bisma Ranjah     Student
# 2693       3123420457      None             Aolani Cano     Student
# 2694       3177355944      None          Conner Nicoson     Student
# 2695       7738860112      None                Soha Ali     Student
#
#      Department Phone Type          Location          Address
# 0       Student       VOIP  Student Location  Student Address
# 1       Student       VOIP  Student Location  Student Address
# 2       Student       VOIP  Student Location  Student Address
# 3       Student       VOIP  Student Location  Student Address
# 4       Student       VOIP  Student Location  Student Address
# ...         ...        ...               ...              ...
# 2691    Student       VOIP  Student Location  Student Address
# 2692    Student       VOIP  Student Location  Student Address
# 2693    Student       VOIP  Student Location  Student Address
# 2694    Student       VOIP  Student Location  Student Address
# 2695    Student       VOIP  Student Location  Student Address
#
# [2696 rows x 8 columns]

# %%
directory_df = pd.concat([d_merge,student_df])
directory_df
# Out:
#      Directory Number Extension             Name           Person Type  \
# 0          7656584070      4070    Tamara Stasik               Faculty
# 1          7656584091      4091   Corinne Wagner                 Staff
# 2          7656584159      4159   Valerie O'Hair                 Staff
# 3          7656584303      4303   Jeane Pope Lab  Not Staff or Faculty
# 4          7656584358      4358  Bridget Gourley               Faculty
# ...               ...       ...              ...                   ...
# 2691       7734410420      None   Tamariya Handy               Student
# 2692       9196274369      None     Bisma Ranjah               Student
# 2693       3123420457      None      Aolani Cano               Student
# 2694       3177355944      None   Conner Nicoson               Student
# 2695       7738860112      None         Soha Ali               Student
#
#                  Department Phone Type          Location          Address
# 0     Academic Affairs Dept       VOIP     Harrison Hall   7 E Larabee St
# 1     Academic Affairs Dept       VOIP     Harrison Hall   7 E Larabee St
# 2     Academic Affairs Dept       VOIP     Harrison Hall   7 E Larabee St
# 3     Academic Affairs Dept       VOIP     Harrison Hall   7 E Larabee St
# 4     Academic Affairs Dept       VOIP     Harrison Hall   7 E Larabee St
# ...                     ...        ...               ...              ...
# 2691                Student       VOIP  Student Location  Student Address
# 2692                Student       VOIP  Student Location  Student Address
# 2693                Student       VOIP  Student Location  Student Address
# 2694                Student       VOIP  Student Location  Student Address
# 2695                Student       VOIP  Student Location  Student Address
#
# [3963 rows x 8 columns]

# %%
directory_df.to_csv("Directory Master.csv")
